# %%
import pandas as pd

# set files path
sales1 = '/home/adalaber/Escritorio/project-da-promo-A-module-2-team-2/txt_csv.csv'
sales2 = '/home/adalaber/Escritorio/project-da-promo-A-module-2-team-2/exported_db_data.csv'
sales3 = '/home/adalaber/Escritorio/project-da-promo-A-module-2-team-2/xml_csv.csv'

print("*** Merging multiple csv files into a single pandas dataframe ***")

# merge files
dataFrame = pd.concat(
   map(pd.read_csv, [sales1, sales2, sales3]), ignore_index=True)
print(dataFrame)
# Out:
# *** Merging multiple csv files into a single pandas dataframe ***
#         Unnamed: 0  index         Q3                 Q4  \
# 0              0.0    0.0      India  Bachelor’s degree
# 1              1.0    1.0  Indonesia    Master’s degree
# 2              2.0    2.0   Pakistan    Master’s degree
# 3              3.0    3.0     Mexico    Doctoral degree
# 4              4.0    4.0      India    Doctoral degree
# ...            ...    ...        ...                ...
# 233753    181807.0    NaN        NaN                NaN
# 233754    181808.0    NaN        NaN                NaN
# 233755    181809.0    NaN        NaN                NaN
# 233756    181810.0    NaN        NaN                NaN
# 233757    181811.0    NaN        NaN                NaN
#
#                              Q5          Q6      Q8  \
# 0                         Other  5-10 years  Python
# 1       Program/Project Manager   20+ years  Python
# 2             Software Engineer   1-3 years  Python
# ...
