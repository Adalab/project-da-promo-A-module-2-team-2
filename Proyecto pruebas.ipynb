# %%
import pandas as pd

import xml.etree.ElementTree as ET

# %%
archivo_txt = pd.read_csv("./data_txt_clean.txt", sep= ";")
archivo_txt.head()
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2      2   Pakistan    Master’s degree        Software Engineer   1-3 years
# 3      3     Mexico    Doctoral degree       Research Scientist   20+ years
# 4      4      India    Doctoral degree                    Other   < 1 years
#
#        Q8                                                Q11  \
# 0  Python                                           A laptop
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2  Python                                           A laptop
# 3  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 4  Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#                   Q13                                    Q15  \
# 0           2-5 times                             5-10 years
# ...

# %%
archivo_csv = pd.read_csv("./exported_db_data.csv")
archivo_csv.head()
# Out:
#    index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# 0      0                NaN  Colab Notebooks        NaN        NaN        NaN
# 1      1   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2      2   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3      3                NaN  Colab Notebooks        NaN        NaN        NaN
# 4      4                NaN              NaN        NaN        NaN        NaN
#
#   Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9 Q10_Part_10  \
# 0        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN
#
#             Q10_Part_11 Q10_Part_12 Q10_Part_13 Q10_Part_14 Q10_Part_15  \
# ...

# %%
archivo_xml = pd.read_csv("./data_xml_clean.xml")
archivo_xml.head()
# Out:
#                      <data>
# 0                     <row>
# 1      <level_0>0</level_0>
# 2          <index>0</index>
# 3          <time>910</time>
# 4          <age>50-54</age>

# %%
tree = ET.parse("data_xml_clean.xml")
root = tree.getroot()

edad = []
time = []
gender = []
index = []

for child in root:
    for subchild in child:
        if subchild.tag == "age":
            edad.append(subchild.text)
        elif subchild.tag == "time":
            time.append(subchild.text)
        elif subchild.tag == "gender":
            gender.append(subchild.text)
        elif subchild.tag == "index":
            index.append(subchild.text)
#print(time)

edad
# Out:
# ['50-54',
#  '50-54',
#  '22-24',
#  '45-49',
#  '45-49',
#  '25-29',
#  '18-21',
#  '30-34',
#  '22-24',
#  '30-34',
#  '40-44',
#  '18-21',
#  '18-21',
#  '45-49',
#  '22-24',
#  '35-39',
#  '50-54',
#  '18-21',
#  '22-24',
#  '30-34',
#  '70+',
#  '25-29',
#  '30-34',
#  '35-39',
#  '18-21',
#  '25-29',
#  '45-49',
#  '22-24',
#  '22-24',
#  '18-21',
#  '22-24',
#  '30-34',
#  '22-24',
#  '30-34',
#  '22-24',
#  '30-34',
#  '25-29',
#  '30-34',
#  '22-24',
#  '18-21',
#  '25-29',
#  '25-29',
#  '55-59',
#  '30-34',
#  '18-21',
#  '40-44',
#  '22-24',
#  '18-21',
#  '25-29',
#  '30-34',
#  '25-29',
#  '40-44',
#  '40-44',
#  '40-44',
#  '30-34',
#  '22-24',
#  '30-34',
#  '35-39',
#  '18-21',
#  '35-39',
#  '18-21',
#  '18-21',
#  '30-34',
#  '18-21',
#  '18-21',
#  '40-44',
#  '30-34',
#  '30-34',
#  '35-39',
#  '40-44',
#  '25-29',
#  '22-24',
#  '30-34',
#  '45-49',
#  '22-24',
#  '40-44',
#  '50-54',
#  '22-24',
#  '25-29',
#  '22-24',
#  '35-39',
#  '30-34',
#  '30-34',
# ...

# %%
df_xml = pd.DataFrame(list(zip(index,edad,time,gender)), columns = ["index","edad","time", "gender"])
df_xml
# Out:
#        index   edad  time gender
# 0          0  50-54   910    Man
# 1          1  50-54   784    Man
# 2          2  22-24   924    Man
# 3          3  45-49   575    Man
# 4          4  45-49   781    Man
# ...      ...    ...   ...    ...
# 25968  25968  30-34  1756    Man
# 25969  25969  22-24   253    Man
# 25970  25970  50-54   494    Man
# 25971  25971  45-49   277    Man
# 25972  25972  18-21   255    Man
#
# [25973 rows x 4 columns]

# %%
print(archivo_txt.shape)
print(df_xml.shape)
print(archivo_csv.shape)
# Out:
# (25973, 27)
# (25973, 4)
# (25973, 18)

# %%
concat_archivos = pd.concat([df_xml, archivo_txt, archivo_csv], axis=1)
concat_archivos.head()
# Out:
#    index   edad time gender  index         Q3                 Q4  \
# 0      0  50-54  910    Man      0      India  Bachelor’s degree
# 1      1  50-54  784    Man      1  Indonesia    Master’s degree
# 2      2  22-24  924    Man      2   Pakistan    Master’s degree
# 3      3  45-49  575    Man      3     Mexico    Doctoral degree
# 4      4  45-49  781    Man      4      India    Doctoral degree
#
#                         Q5          Q6      Q8  ... Q10_Part_8 Q10_Part_9  \
# 0                    Other  5-10 years  Python  ...        NaN        NaN
# 1  Program/Project Manager   20+ years  Python  ...        NaN        NaN
# 2        Software Engineer   1-3 years  Python  ...        NaN        NaN
# 3       Research Scientist   20+ years  Python  ...        NaN        NaN
# 4                    Other   < 1 years  Python  ...        NaN        NaN
#
#   Q10_Part_10           Q10_Part_11 Q10_Part_12 Q10_Part_13 Q10_Part_14  \
# ...

# %%
concat_archivos.shape
concat_archivos.columns
new_df = concat_archivos.copy()


del new_df["index"]
print(new_df.columns)
new_df.head()
# Out:
# Index(['edad', 'time', 'gender', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11', 'Q13',
#        'Q15', 'Q20', 'Q21', 'Q22', 'Q23', 'Q25', 'Q26', 'Q33', 'Q35', 'Q41',
#        'Q7', 'Q9', 'Q12', 'Q14', 'Q16', 'Q17', 'Q24', 'Q32', 'Q34',
#        'Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4', 'Q10_Part_5',
#        'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9', 'Q10_Part_10',
#        'Q10_Part_11', 'Q10_Part_12', 'Q10_Part_13', 'Q10_Part_14',
#        'Q10_Part_15', 'Q10_Part_16', 'Q10_OTHER'],
#       dtype='object')
#     edad time gender         Q3                 Q4                       Q5  \
# 0  50-54  910    Man      India  Bachelor’s degree                    Other
# 1  50-54  784    Man  Indonesia    Master’s degree  Program/Project Manager
# 2  22-24  924    Man   Pakistan    Master’s degree        Software Engineer
# 3  45-49  575    Man     Mexico    Doctoral degree       Research Scientist
# ...

# %% [markdown]
# **Guardar el archivo en CSV**

# %%
#archivo_xml.to_csv("xml_csv.csv")

# %%
archivo_txt = pd.read_csv("/Users/lidiacarriedoponce/Desktop/project-da-promo-A-module-2-team-2/archivos descargados/data_txt_clean.txt", sep= ";")
archivo_txt.head()
#archivo_txt.to_csv("txt_csv.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_19365/429515524.py in <module>
# ----> 1 archivo_txt = pd.read_csv("/Users/lidiacarriedoponce/Desktop/project-da-promo-A-module-2-team-2/archivos descargados/data_txt_clean.txt", sep= ";")
#       2 archivo_txt.head()
#       3 #archivo_txt.to_csv("txt_csv.csv")
#
# ~/Descargas/yes/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd

# set files path
archivo_txt2 = "./txt_csv.csv"
archivo_csv2 = "./exported_db_data.csv"
archivo_xml2 = "./xml_csv.csv"

print("*** Merging multiple csv files into a single pandas dataframe ***")

# merge files
dataFrame = pd.concat(
   map(pd.read_csv, [archivo_xml2, archivo_txt2, archivo_csv2]), ignore_index=True)
dataFrame
